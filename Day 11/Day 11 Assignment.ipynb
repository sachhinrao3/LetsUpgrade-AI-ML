# %%
import o
# os.getcwd()
# Out:
# 'C:\\Users\\admin\\Downloads\\LetsUpgade\\Coding files\\Day 10'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
filepath = 'C:\\Users\\admin\\Downloads\\LetsUpgade\\Assignment\\Day 7\\general_data.csv'
df = pd.read_csv(filepath)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  JobLevel  \
# 0          2  Life Sciences              1           1  Female         1
# 1          1  Life Sciences              1           2  Female         1
# 2          4          Other              1           3    Male         4
# 3          5  Life Sciences              1           4    Male         3
# 4          1        Medical              1           5    Male         1
#
# ...

# %%
# Total null values present in each columns
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %% [markdown]
# __Filling the null value with forward fill method__

# %%
df.fillna(method= 'ffill', inplace= True)

# %%
#  Total null values present in the dataset 
df.isnull().sum().sum()
# Out:
# 0

# %%
df.describe(include='all').T
# Out:
#                         count unique                     top  freq      mean  \
# Age                      4410    NaN                     NaN   NaN   36.9238
# Attrition                4410      2                      No  3699       NaN
# BusinessTravel           4410      3           Travel_Rarely  3129       NaN
# Department               4410      3  Research & Development  2883       NaN
# DistanceFromHome         4410    NaN                     NaN   NaN   9.19252
# Education                4410    NaN                     NaN   NaN   2.91293
# EducationField           4410      6           Life Sciences  1818       NaN
# EmployeeCount            4410    NaN                     NaN   NaN         1
# EmployeeID               4410    NaN                     NaN   NaN    2205.5
# Gender                   4410      2                    Male  2646       NaN
# JobLevel                 4410    NaN                     NaN   NaN   2.06395
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   int64
#  1   Attrition                4410 non-null   object
#  2   BusinessTravel           4410 non-null   object
#  3   Department               4410 non-null   object
#  4   DistanceFromHome         4410 non-null   int64
#  5   Education                4410 non-null   int64
#  6   EducationField           4410 non-null   object
#  7   EmployeeCount            4410 non-null   int64
#  8   EmployeeID               4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
# 30      False
# 31      False
# 32      False
# 33      False
# 34      False
# 35      False
# 36      False
# 37      False
# 38      False
# 39      False
# 40      False
# 41      False
# 42      False
# 43      False
# 44      False
# 45      False
# 46      False
# 47      False
# 48      False
# 49      False
# 50      False
# 51      False
# 52      False
# 53      False
# 54      False
# 55      False
# 56      False
# 57      False
# 58      False
# 59      False
# 60      False
# 61      False
# ...

# %%
df.drop_duplicates()
df.shape
# Out:
# (4410, 24)

# %% [markdown]
# __3 columns have same values in each row. So we can drop them from our dataset__

# %%
drop_col = ['EmployeeCount', 'EmployeeID', 'Over18', 'StandardHours']
df.drop(drop_col, axis= 1, inplace= True)
df.shape
# Out:
# (4410, 20)

# %% [markdown]
# __Convert 'Attrition' column values in integer type; as Yes to "0" and No to "1"__

# %%
df.replace({'Attrition' : {'Yes' : 0, 'No' : 1}}, inplace=True)
df.Attrition.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: Attrition, dtype: int64

# %% [markdown]
# __Correlation Matrix for our data set.__

# %%
df.corr()
# Out:
#                               Age  Attrition  DistanceFromHome  Education  \
# Age                      1.000000   0.159205          0.006963  -0.035706
# Attrition                0.159205   1.000000          0.009730   0.015111
# DistanceFromHome         0.006963   0.009730          1.000000  -0.008638
# Education               -0.035706   0.015111         -0.008638   1.000000
# JobLevel                -0.002884   0.010290         -0.037329   0.045746
# MonthlyIncome           -0.044314   0.031176         -0.021607   0.006410
# NumCompaniesWorked       0.296805  -0.041736         -0.013006  -0.016912
# PercentSalaryHike       -0.033137  -0.032533          0.038125  -0.040531
# StockOptionLevel        -0.031753   0.006839          0.011169   0.001261
# TotalWorkingYears        0.678857   0.169622          0.007762  -0.009485
# TrainingTimesLastYear   -0.027308   0.049431         -0.009001   0.010472
# YearsAtCompany           0.311309   0.134392          0.031684   0.006080
# ...

# %% [markdown]
# __We can also plot graph for each column to get correlation between them.__

# %%
plt.scatter(df.YearsAtCompany,df.Attrition)

# %%
# int_col= df.select_dtypes(exclude= 'object')
# int_col
plt.scatter(df.TotalWorkingYears,df.Attrition)

# %% [markdown]
# ## By checking correlation between different columns(by correlation matrix) we can define relation between those columns with Attrition columns(Dependent column):

# %% [markdown]
# __Attrition column is weakly positive related to the Age column.__
#
# __It's a Classification problem in which Attriton value is either 1(Yes) and 0(No) only.__
#
# __So most of the columns are showing no relation to the Attrition column.__
#
# __But with TotalWorkingYear column, YearsAtCompany column,and YearsUnderCurrManager column is low postive realated to the Attrition column.__
#
# __YearsAtCompany and TotalWorkingYears columns are highly positive correlated to each other.__
#
# __YearsSinceLastPrommotion and YearsAtCompany columns are also highly positive correlated to each other.__
