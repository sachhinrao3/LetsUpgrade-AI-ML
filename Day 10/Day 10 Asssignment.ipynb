# %%
import pandas as pd
import numpy as np

# %%
filepath = 'C:\\Users\\admin\\Downloads\\LetsUpgade\\Assignment\\Day 7\\general_data.csv'
df = pd.read_csv(filepath)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
df.Age.mean()
# Out:
# 36.923809523809524

# %% [markdown]
# # Hypothesis statement based on given dataset

# %% [markdown]
# __1. The average age of the Employees is less than 40.__
#
# __2. The total count of Male Emplyees is more than Female Employees.__
#
# __3. Employees who are not promoted from last 11 years is equal to 72.__
#
# __4. Employees whose education field is 'Life Sciences" are greater than 50.__
#
# __5. Employees who are working in Sales is equal to 90.__
#
# __6. Less than 1000 employees left there job last year.__
#
# __7. Employees whose Distance from home is more than 10 are equal to 198.__
#
# __8. More than 670 employees are married.__
#
# __9. Employees whose salary is more than 50,000 are more than 1500.__
#
# __10. Employees whose working year more than 10 are less than 1000.__
#
# __11. Count of employees who are working under current manager from 6 tears are equal to 289.__
