# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
filepath = 'C:\\Users\\admin\\Downloads\\LetsUpgade\\Assignment\\Day 7\\general_data.csv'
df = pd.read_csv(filepath)

# %%
df.shape
# Out:
# (4410, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   int64
#  1   Attrition                4410 non-null   object
#  2   BusinessTravel           4410 non-null   object
#  3   Department               4410 non-null   object
#  4   DistanceFromHome         4410 non-null   int64
#  5   Education                4410 non-null   int64
#  6   EducationField           4410 non-null   object
#  7   EmployeeCount            4410 non-null   int64
#  8   EmployeeID               4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
# ...

# %%
df.head(6)
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
# 5   46        No      Travel_Rarely  Research & Development                 8
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
# ...

# %%
df.describe().T
# Out:
#                           count          mean           std      min  \
# Age                      4410.0     36.923810      9.133301     18.0
# DistanceFromHome         4410.0      9.192517      8.105026      1.0
# Education                4410.0      2.912925      1.023933      1.0
# EmployeeCount            4410.0      1.000000      0.000000      1.0
# EmployeeID               4410.0   2205.500000   1273.201673      1.0
# JobLevel                 4410.0      2.063946      1.106689      1.0
# MonthlyIncome            4410.0  65029.312925  47068.888559  10090.0
# NumCompaniesWorked       4391.0      2.694830      2.498887      0.0
# PercentSalaryHike        4410.0     15.209524      3.659108     11.0
# StandardHours            4410.0      8.000000      0.000000      8.0
# StockOptionLevel         4410.0      0.793878      0.851883      0.0
# TotalWorkingYears        4401.0     11.279936      7.782222      0.0
# TrainingTimesLastYear    4410.0      2.799320      1.288978      0.0
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %% [markdown]
# __The management has contracted an HR analytics firm to understand what factors they
# should focus on, in order to curb attrition.__
#
# __After checking the full profile report of given data, we can check for different given attributes__

# %%
#  Total count of employees whether they left previous year or not 
df['Attrition'].value_counts()
# Out:
# No     3699
# Yes     711
# Name: Attrition, dtype: int64

# %% [markdown]
# __We want to work on those employees who left company last year__

# %%
# Select employees who left in the last year (Attrition == 'Yes')
dt = df.loc[(df.Attrition=='Yes')]
dt.head()
# Out:
#     Age Attrition     BusinessTravel              Department  \
# 1    31       Yes  Travel_Frequently  Research & Development
# 6    28       Yes      Travel_Rarely  Research & Development
# 13   47       Yes         Non-Travel  Research & Development
# 28   44       Yes  Travel_Frequently  Research & Development
# 30   26       Yes      Travel_Rarely  Research & Development
#
#     DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 1                 10          1  Life Sciences              1           2
# 6                 11          2        Medical              1           7
# 13                 1          1        Medical              1          14
# 28                 1          2        Medical              1          29
# 30                 4          3        Medical              1          31
#
#     Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
dt.columns.any() ==  'JobStatisfaction'
# Out:
# False

# %% [markdown]
# __JobStatisfaction Attribute is missing from the given data__

# %% [markdown]
# __3 columns have all same values so we can drop these columns.__

# %%
drop_col = ['EmployeeCount', 'EmployeeID', 'Over18', 'StandardHours']
dt.drop(drop_col, axis= 1, inplace= True)
dt.shape
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# (711, 20)

# %%
# To print all rows and columns 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
dt
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 1      31       Yes  Travel_Frequently  Research & Development
# 6      28       Yes      Travel_Rarely  Research & Development
# 13     47       Yes         Non-Travel  Research & Development
# 28     44       Yes  Travel_Frequently  Research & Development
# 30     26       Yes      Travel_Rarely  Research & Development
# 35     26       Yes      Travel_Rarely  Research & Development
# 38     18       Yes      Travel_Rarely  Research & Development
# 59     52       Yes      Travel_Rarely  Research & Development
# 65     28       Yes      Travel_Rarely  Research & Development
# 69     39       Yes      Travel_Rarely  Research & Development
# 78     29       Yes      Travel_Rarely  Research & Development
# 99     21       Yes  Travel_Frequently  Research & Development
# 105    33       Yes      Travel_Rarely         Human Resources
# 108    41       Yes  Travel_Frequently  Research & Development
# ...

# %%
dt.describe()
# Out:
#               Age  DistanceFromHome   Education  EmployeeCount   EmployeeID  \
# count  711.000000        711.000000  711.000000          711.0   711.000000
# mean    33.607595          9.012658    2.877637            1.0  2191.767932
# std      9.675693          7.772368    1.014233            0.0  1270.136654
# min     18.000000          1.000000    1.000000            1.0     2.000000
# 25%     28.000000          2.000000    2.000000            1.0  1072.000000
# 50%     32.000000          7.000000    3.000000            1.0  2165.000000
# 75%     39.000000         15.000000    4.000000            1.0  3341.000000
# max     58.000000         29.000000    5.000000            1.0  4403.000000
#
#          JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  711.000000     711.000000          707.000000         711.000000
# mean     2.037975   61682.616034            2.936351          15.481013
# ...

# %%
dt.isnull().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         4
# PercentSalaryHike          0
# StockOptionLevel           0
# TotalWorkingYears          2
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %%
dt.fillna(method= 'bfill', inplace= True)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\pandas\core\frame.py:4153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
dt.duplicated()
# Out:
# 1       False
# 6       False
# 13      False
# 28      False
# 30      False
# 35      False
# 38      False
# 59      False
# 65      False
# 69      False
# 78      False
# 99      False
# 105     False
# 108     False
# 110     False
# 112     False
# 120     False
# 124     False
# 127     False
# 147     False
# 156     False
# 157     False
# 163     False
# 164     False
# 177     False
# 178     False
# 181     False
# 182     False
# 185     False
# 195     False
# 199     False
# 205     False
# 211     False
# 221     False
# 222     False
# 224     False
# 237     False
# 246     False
# 255     False
# 256     False
# 267     False
# 270     False
# 282     False
# 289     False
# 304     False
# 308     False
# 310     False
# 315     False
# 327     False
# 331     False
# 333     False
# 337     False
# 340     False
# 349     False
# 350     False
# 356     False
# 378     False
# 387     False
# 398     False
# 402     False
# 404     False
# 405     False
# ...

# %%
dt.drop_duplicates()
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 1      31       Yes  Travel_Frequently  Research & Development
# 6      28       Yes      Travel_Rarely  Research & Development
# 13     47       Yes         Non-Travel  Research & Development
# 28     44       Yes  Travel_Frequently  Research & Development
# 30     26       Yes      Travel_Rarely  Research & Development
# 35     26       Yes      Travel_Rarely  Research & Development
# 38     18       Yes      Travel_Rarely  Research & Development
# 59     52       Yes      Travel_Rarely  Research & Development
# 65     28       Yes      Travel_Rarely  Research & Development
# 69     39       Yes      Travel_Rarely  Research & Development
# 78     29       Yes      Travel_Rarely  Research & Development
# 99     21       Yes  Travel_Frequently  Research & Development
# 105    33       Yes      Travel_Rarely         Human Resources
# 108    41       Yes  Travel_Frequently  Research & Development
# ...

# %%
dt.shape
# Out:
# (711, 20)

# %%
dt[dt.columns].skew()
# Out:
# Age                        0.712699
# DistanceFromHome           0.964420
# Education                 -0.216055
# JobLevel                   1.063605
# MonthlyIncome              1.540705
# NumCompaniesWorked         0.862081
# PercentSalaryHike          0.763693
# StockOptionLevel           0.959139
# TotalWorkingYears          1.668292
# TrainingTimesLastYear      0.422124
# YearsAtCompany             2.670876
# YearsSinceLastPromotion    2.208164
# YearsWithCurrManager       1.025486
# dtype: float64

# %%
dt[dt.columns].kurt()
# Out:
# Age                       -0.073144
# DistanceFromHome          -0.041771
# Education                 -0.616494
# JobLevel                   0.632019
# MonthlyIncome              1.658176
# NumCompaniesWorked        -0.560748
# PercentSalaryHike         -0.418411
# StockOptionLevel           0.251598
# TotalWorkingYears          3.631785
# TrainingTimesLastYear      0.960134
# YearsAtCompany             9.456107
# YearsSinceLastPromotion    4.775929
# YearsWithCurrManager       0.242923
# dtype: float64

# %%
dt[dt.columns].var()
# Out:
# Age                        9.361904e+01
# DistanceFromHome           6.040970e+01
# Education                  1.028668e+00
# JobLevel                   1.118274e+00
# MonthlyIncome              2.006329e+09
# NumCompaniesWorked         7.227816e+00
# PercentSalaryHike          1.425281e+01
# StockOptionLevel           7.377073e-01
# TotalWorkingYears          5.162360e+01
# TrainingTimesLastYear      1.333642e+00
# YearsAtCompany             3.530259e+01
# YearsSinceLastPromotion    9.913888e+00
# YearsWithCurrManager       9.852808e+00
# dtype: float64

# %%
from pandas_profiling import ProfileReport


profile = ProfileReport(dt)
profile.to_file(output_file = 'report.html')
# Out:
# ...
# C:\Users\admin\Anaconda3\lib\site-packages\pandas_profiling\visualisation\plot.py:154: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("RdBu"))
#   cmap.set_bad(cmap_bad)
# ...

# %% [markdown]
# ## Inference from the analysis.
#
# __75 percent employees who left there jobs have job level 1 & 2__
# __10.5 percent(75) employees who left last year have Total working years is 10.__
# __While 16.7 percent(119) employees are freshers__
# __ Maximum employees who left there jobs are from sales

# %%
plt.figure(figsize=(11,6))
plt.plot(dt.YearsAtCompany,'rs')
plt.xlabel('Years at company')
# Out:
# Text(0.5, 0, 'Years at company')

# %%
plt.plot(dt.MonthlyIncome, 'bo')
plt.xlabel('Monthly Income')
plt.show()

# %%
plt.boxplot(dt.MonthlyIncome)
plt.show()

# %% [markdown]
# __Monthly Income is Right Skewed with several outliers__

# %%
plt.boxplot(dt.Education)
plt.show()

# %% [markdown]
# __Values of Education column is normally distributed.__

# %%
plt.boxplot(dt.YearsAtCompany)
plt.show()

# %% [markdown]
# __Years at company column values are skewed right with several outliers.__
